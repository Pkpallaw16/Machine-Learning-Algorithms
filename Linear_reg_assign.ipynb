# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.datasets import load_boston
import pandas as pd
boston = load_boston()
boston.data
print(boston.data.shape)
bos = pd.DataFrame(boston.data)
bos.columns = boston.feature_names
bos['price']=boston.target

# Initialise the Scaler 
scaler = StandardScaler()  
scaler.fit(bos)
bos.head(10)
# Out:
# (506, 13)
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0  222.0
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0  311.0
#
#    PTRATIO       B  LSTAT  price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# ...

# %%
X = bos.drop('price', axis = 1)
Y = bos['price']
x_train,x_test,y_train,y_test=train_test_split(X, Y, test_size = 0.30, random_state = 10)
m_cur=np.zeros(len(bos.columns))

# %%
def gradient_descent(features,y):
  m_cur=np.zeros(features.shape[1])
  
  c_cur=0
  learning_rate=0.001
  itr=100
  n=len(features)
  y_pred=np.zeros(len(features))
  m_d=np.zeros(features.shape[1])
  for i in range(itr):
    for j in range(len(features)):
      y_pred[j]=np.sum(features.iloc[j]*m_cur) + c_cur
    cost = (1/n) * sum([diff**2 for diff in (y-y_pred)])
    print(cost)
    q=0
    for featr in x_train.columns:
      m_d[q]=-(2/n)*sum(features[featr]*(y-y_pred))
      q+=1
    c_d=-(2/n)*sum(y-y_pred)
    m_cur=m_cur-(learning_rate*m_d)
    c_cur=c_cur-(learning_rate* c_d)
    
    #print ("b {}, cost {} iteration {}".format(b_cur,cost,i))
  return y_pred    
prediction=gradient_descent(x_train,y_train)
#print(prediction)
# Out:
# 560.4288135593217
# 174129244.73478657
# 70456090747661.84
# 2.8528094053170192e+19
# 1.1551242569148964e+25
# 4.6771862024521184e+30
# 1.8938283603880358e+36
# 7.66825544968094e+41
# 3.104935107715538e+47
# 1.2572119025489192e+53
# 5.090546865160062e+58
# 2.0612012449017178e+64
# 8.34596102250167e+69
# 3.37934326215868e+75
# 1.3683218568488095e+81
# 5.540439543079068e+86
# 2.2433662209567367e+92
# 9.083560901980005e+97
# 3.678003078106041e+103
# 1.4892514938286815e+109
# 6.030092864993008e+114
# 2.4416305849697236e+120
# 9.886348430998027e+125
# 4.003057870456232e+131
# 1.620868658035342e+137
# 6.563020799651509e+142
# 2.6574171696840297e+148
# 1.0760084767835058e+154
# 4.356840376129661e+159
# 1.764117892436719e+165
# 7.143047873560107e+170
# 2.8922745550465963e+176
# 1.1711040230786984e+182
# 4.741889494820172e+187
# 1.9200272168798496e+193
# 7.774336617473603e+198
# 3.1478881815024344e+204
# 1.2746039296743026e+210
# 5.160968509261897e+215
# 2.0897155056158596e+221
# ...
